# %% [markdown]
# ## Neural Networks for Sentiment Analysis

# %% [markdown]
# ![image.png](attachment:0324384f-ee60-46e1-9ce7-85cef9c13946.png)

# %% [markdown]
# ![image.png](attachment:3104c541-8a36-4678-a5c8-105ae44f3ac1.png)

# %% [markdown]
# ![image.png](attachment:afde2b45-93af-4a51-bdd5-6ef751986613.png)

# %% [markdown]
# **Steps in represnting tweets:**
# Word -> Vector Represntaiton -> Fill Vector to match longest tweet (padding)
